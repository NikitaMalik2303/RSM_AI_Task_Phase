# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
X = np.array([10,20,30,40,50,60,70,80,90])
Y = np.array([15,25,35,45,57,67,77,88,98])

# %%
X = X.reshape(-1,1)
Y = Y.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,Y)
# Out:
# LinearRegression()

# %%
Y_pred = lr.predict(Y)

# %%
print(Y_pred)
# Out:
# [[ 19.75833333]
#  [ 30.20833333]
#  [ 40.65833333]
#  [ 51.10833333]
#  [ 63.64833333]
#  [ 74.09833333]
#  [ 84.54833333]
#  [ 96.04333333]
#  [106.49333333]]

# %%
plt.scatter(X, Y, c = "red")
plt.plot(X, Y_pred, c = "blue")
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Linear Regression")
plt.show()

# %%
lr.score(X,Y)
# Out:
# 0.9997177296307599
